# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path1 = '/content/drive/My Drive/ISRO/corpus/AndasolChangePair/Andasol_09051987.jpg'
path2 = '/content/drive/My Drive/ISRO/corpus/AndasolChangePair/Andasol_09122013.jpg'

# %%
import numpy as np
import cv2
from matplotlib import pyplot as plt

# %%
X1 = cv2.imread(path1, 0)
X2 = cv2.imread(path2, 0)
plt.imshow(X1)
plt.show()
plt.imshow(X2)
plt.show()

# %%
frame = X1
bgsub = cv2.createBackgroundSubtractorMOG2(500, varThreshold = 260)
mask1 = bgsub.apply(X1, )
plt.imshow(mask1)
plt.show()
mask1 = bgsub.apply(X2)
plt.imshow(mask1)
plt.show()
print(mask1.shape)
# Out:
# (1200, 1200)

# %%
from google.colab.patches import cv2_imshow
mask1 = cv2.resize(mask1, (500, 500))
_, mask1 = cv2.threshold(mask1, 10, 255, cv2.THRESH_BINARY)
cv2_imshow(mask1)
# Out:
# <PIL.Image.Image image mode=L size=500x500 at 0x7FF790FA15C0>
